# %% [markdown]
# ## Importing libraries and data

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# import libraries for modelling
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

# %%
#we are using a dataset from kaggle. Don't forget to load a kaggle.json file before running this cell
! pip install kaggle

! mkdir ~/.kaggle

! cp kaggle.json ~/.kaggle/

! chmod 600 ~/.kaggle/kaggle.json
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.13)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.26.15)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.27.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (2.0.12)

# %%
# !pip install torch==1.13.1
! pip install sdv
! pip install faker
! pip install realtabformer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.13.1
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1) (4.5.0)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==1.13.1)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 55.9 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==1.13.1)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.0 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==1.13.1)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==1.13.1)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 65.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1) (0.40.0)
# Installing collected packages: nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, nvidia-cudnn-cu11, torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.1+cu118 requires torch==2.0.0, but you have torch 1.13.1 which is incompatible.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 1.13.1 which is incompatible.
# torchtext 0.15.1 requires torch==2.0.0, but you have torch 1.13.1 which is incompatible.
# torchvision 0.15.1+cu118 requires torch==2.0.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 torch-1.13.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sdv
#   Downloading sdv-1.0.1-py2.py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.7/115.7 kB 487.3 kB/s eta 0:00:00
# Collecting Faker<15,>=10 (from sdv)
#   Downloading Faker-14.2.1-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.3 MB/s eta 0:00:00
# Requirement already satisfied: graphviz<1,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from sdv) (0.20.1)
# Requirement already satisfied: tqdm<5,>=4.15 in /usr/local/lib/python3.10/dist-packages (from sdv) (4.65.0)
# Collecting copulas<0.9,>=0.8.0 (from sdv)
#   Downloading copulas-0.8.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 7.5 MB/s eta 0:00:00
# Collecting ctgan<0.8,>=0.7.1 (from sdv)
#   Downloading ctgan-0.7.1-py2.py3-none-any.whl (26 kB)
# Collecting deepecho<0.5,>=0.4.0 (from sdv)
#   Downloading deepecho-0.4.0-py2.py3-none-any.whl (28 kB)
# Collecting rdt<2,>=1.3.0 (from sdv)
#   Downloading rdt-1.4.1-py2.py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 3.9 MB/s eta 0:00:00
# Collecting sdmetrics<0.10,>=0.9.1 (from sdv)
#   Downloading sdmetrics-0.9.3-py2.py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle<3.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from sdv) (2.2.1)
# Collecting boto3<2,>=1.15.0 (from sdv)
#   Downloading boto3-1.26.124-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 16.8 MB/s eta 0:00:00
# Collecting botocore<2,>=1.18 (from sdv)
#   Downloading botocore-1.29.124-py3-none-any.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 86.4 MB/s eta 0:00:00
# Collecting numpy<2,>=1.23.3 (from sdv)
#   Downloading numpy-1.24.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 71.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas<2,>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from sdv) (1.5.3)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2,>=1.15.0->sdv)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0 (from boto3<2,>=1.15.0->sdv)
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<2,>=1.18->sdv) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<2,>=1.18->sdv) (1.26.15)
# Requirement already satisfied: matplotlib<4,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from copulas<0.9,>=0.8.0->sdv) (3.7.1)
# Requirement already satisfied: scipy<2,>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from copulas<0.9,>=0.8.0->sdv) (1.10.1)
# Collecting packaging<22,>=20 (from ctgan<0.8,>=0.7.1->sdv)
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn<2,>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from ctgan<0.8,>=0.7.1->sdv) (1.2.2)
# Requirement already satisfied: torch<2,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from ctgan<0.8,>=0.7.1->sdv) (1.13.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2,>=1.5.0->sdv) (2022.7.1)
# Requirement already satisfied: psutil<6,>=5.7 in /usr/local/lib/python3.10/dist-packages (from rdt<2,>=1.3.0->sdv) (5.9.5)
# Requirement already satisfied: plotly<6,>=5.10.0 in /usr/local/lib/python3.10/dist-packages (from sdmetrics<0.10,>=0.9.1->sdv) (5.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.9,>=0.8.0->sdv) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.9,>=0.8.0->sdv) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.9,>=0.8.0->sdv) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.9,>=0.8.0->sdv) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.9,>=0.8.0->sdv) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.9,>=0.8.0->sdv) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6,>=5.10.0->sdmetrics<0.10,>=0.9.1->sdv) (8.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2,>=1.18->sdv) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1.1.3->ctgan<0.8,>=0.7.1->sdv) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1.1.3->ctgan<0.8,>=0.7.1->sdv) (3.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch<2,>=1.11.0->ctgan<0.8,>=0.7.1->sdv) (4.5.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch<2,>=1.11.0->ctgan<0.8,>=0.7.1->sdv) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch<2,>=1.11.0->ctgan<0.8,>=0.7.1->sdv) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch<2,>=1.11.0->ctgan<0.8,>=0.7.1->sdv) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch<2,>=1.11.0->ctgan<0.8,>=0.7.1->sdv) (11.7.99)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2,>=1.11.0->ctgan<0.8,>=0.7.1->sdv) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2,>=1.11.0->ctgan<0.8,>=0.7.1->sdv) (0.40.0)
# Installing collected packages: packaging, numpy, jmespath, Faker, botocore, s3transfer, rdt, deepecho, copulas, boto3, sdmetrics, ctgan, sdv
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.1
#     Uninstalling packaging-23.1:
#       Successfully uninstalled packaging-23.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.3 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.24.3 which is incompatible.
# torchtext 0.15.1 requires torch==2.0.0, but you have torch 1.13.1 which is incompatible.
# torchvision 0.15.1+cu118 requires torch==2.0.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed Faker-14.2.1 boto3-1.26.124 botocore-1.29.124 copulas-0.8.0 ctgan-0.7.1 deepecho-0.4.0 jmespath-1.0.1 numpy-1.24.3 packaging-21.3 rdt-1.4.1 s3transfer-0.6.0 sdmetrics-0.9.3 sdv-1.0.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: faker in /usr/local/lib/python3.10/dist-packages (14.2.1)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting realtabformer
#   Downloading REaLTabFormer-0.1.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 4.3 MB/s eta 0:00:00
# Collecting datasets>=2.6.1 (from realtabformer)
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 39.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from realtabformer) (1.24.3)
# Requirement already satisfied: pandas>=1.3.5 in /usr/local/lib/python3.10/dist-packages (from realtabformer) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from realtabformer) (1.2.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from realtabformer) (1.13.1)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.10/dist-packages (from realtabformer) (4.65.0)
# Collecting transformers>=4.24.0 (from realtabformer)
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 102.8 MB/s eta 0:00:00
# Requirement already satisfied: shapely>=1.8.5.post1 in /usr/local/lib/python3.10/dist-packages (from realtabformer) (2.0.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.6.1->realtabformer) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets>=2.6.1->realtabformer)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.6.1->realtabformer) (2.27.1)
# Collecting xxhash (from datasets>=2.6.1->realtabformer)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 19.7 MB/s eta 0:00:00
# Collecting multiprocess (from datasets>=2.6.1->realtabformer)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.6.1->realtabformer) (2023.4.0)
# Collecting aiohttp (from datasets>=2.6.1->realtabformer)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.4 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.11.0 (from datasets>=2.6.1->realtabformer)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 25.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets>=2.6.1->realtabformer) (21.3)
# Collecting responses<0.19 (from datasets>=2.6.1->realtabformer)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.6.1->realtabformer) (6.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->realtabformer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->realtabformer) (2022.7.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->realtabformer) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->realtabformer) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->realtabformer) (3.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->realtabformer) (4.5.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->realtabformer) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->realtabformer) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->realtabformer) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->realtabformer) (11.7.99)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.13.0->realtabformer) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.13.0->realtabformer) (0.40.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.24.0->realtabformer) (3.12.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.24.0->realtabformer) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers>=4.24.0->realtabformer)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 90.9 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.6.1->realtabformer) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.6.1->realtabformer) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets>=2.6.1->realtabformer)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.8 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets>=2.6.1->realtabformer)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets>=2.6.1->realtabformer)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 33.0 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets>=2.6.1->realtabformer)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 22.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets>=2.6.1->realtabformer)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from packaging->datasets>=2.6.1->realtabformer) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.3.5->realtabformer) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.6.1->realtabformer) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.6.1->realtabformer) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.6.1->realtabformer) (3.4)
# Installing collected packages: tokenizers, xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, transformers, aiohttp, datasets, realtabformer
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.12.0 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.14.1 multidict-6.0.4 multiprocess-0.70.14 realtabformer-0.1.1 responses-0.18.0 tokenizers-0.13.3 transformers-4.28.1 xxhash-3.2.0 yarl-1.9.2

# %%
# !kaggle datasets download -d incarnyx/car-insurance-fraud
# Out:
# Downloading car-insurance-fraud.zip to /content
# 100% 1.82M/1.82M [00:01<00:00, 2.06MB/s]
# 100% 1.82M/1.82M [00:01<00:00, 1.82MB/s]

# %%
# !unzip car-insurance-fraud.zip
# Out:
# Archive:  car-insurance-fraud.zip
#   inflating: Dataset.xlsx

# %% [markdown]
# ## Synthetic Data Generator

# %%
import pandas as pd
import numpy as np
from faker import Faker
import random
from collections import OrderedDict
from sdv.metadata import SingleTableMetadata
from sdv.single_table import CTGANSynthesizer, GaussianCopulaSynthesizer
import torch
import re
from sdv.metadata import SingleTableMetadata
from realtabformer import REaLTabFormer
 


class Generator:

    def __init__(self, data, architecture, n_samples, num_epochs=None, num_bootstrap = None ,categorical_columns=None, sensitive_columns=None):

        """
        :param n_epochs: the number of epochs used for training, default is 200
        :param num_bootstraps: number of bootstraps for the RealTabFormer, default is 500
        :param n_samples: the number of rows to generate
        :param architecture: the chosen architecture, one of ['CTGAN', 'GaussianCopula', 'RealTabFormer']
        :param data: the data that should be trained on, should be in a pandas dataframe
        :param categorical_columns: a list with categorical columns
        :param sensitive_columns: a dict with sensitive columns and what  category they belong to
        The categories can be found in the faker_categorical function

        The metadata: an sdv metadata object required to call CTGAN and other methods
        Also required for similarity checks
        """
        if num_epochs is not None:
          self.num_epochs = num_epochs
        else: 
          # Default value for RealTabFormer and could be enough for CTGAN
          self.num_epochs = 200
        if num_bootstrap is not None:
          self.num_bootstrap = num_bootstrap
        else: 
          # Set to default for RealTabFormer
          self.num_bootstrap = 500 
        self.n_samples = n_samples
        if architecture in ['CTGAN', 'GaussianCopula', 'RealTabFormer']:
            self.architecture = architecture
        else:
            print('The requested architecture is not available')
            raise ValueError
        print('Retrieving metadata, check with generator.metadata')
        self.data = data
        self.metadata = self.create_metadata()
        self.categorical_columns = categorical_columns
        self.sensitive_columns = sensitive_columns

    def create_metadata(self):
        metadata = SingleTableMetadata()
        metadata.detect_from_dataframe(data=self.data)
        return metadata

    def generate(self):
        """
        Based on the chosen architecture, this function returns synthetically generated data
        :return: synthetic data, a pandas dataframe
        """

        #  TODO: Add more generators, especially PATEGAN or other differentially private ones synthcity seems to have
        #  implementations of these, but I have not been able to import their library

        if self.architecture == "CTGAN":
            model = CTGANSynthesizer(metadata=self.metadata, epochs=self.num_epochs, verbose=True)
            model.fit(self.data)
            synth_data = model.sample(self.n_samples)

        elif self.architecture == "GaussianCopula":
            model = GaussianCopulaSynthesizer(metadata=self.metadata)
            model.fit(self.data)
            synth_data = model.sample(self.n_samples)
        elif self.architecture == "RealTabFormer":
            model = REaLTabFormer(
                      model_type="tabular",
                      epochs = self.num_epochs,
                      gradient_accumulation_steps=4,
                      # Output log each 2O steps
                      logging_steps=20)
            model.fit(self.data, num_bootstrap = self.num_bootstrap)
            synth_data = model.sample(n_samples = self.n_samples)


        return synth_data

    def faker_categorical(self, seed=None):
        """
        Instantiates Faker, generates fake data for it
        WARNING: data generated here should not be used for ML models
        :param seed: int, random seed, defaults
        """

        # TODO: Find a way to make this generalizable, f.e. create many attributes, and return the ones asked

        seed = seed or random.seed()
        # We can initialize the faker with multiple locations: can now draw addresses and names from
        # Germany, US, UK, Spain, France, Italy. Either just a list => all equal weights, or an ordered
        # dictionary in which weights can be specified.
        locale_list = ['de_DE', 'en_US', 'en_GB', 'es_ES', 'fr_FR', 'it_IT']
        fake = Faker(locale_list)
        fake.seed_instance(seed)
        # check whether the ID generated is already in use
        used_ids = set()
        output = []
        for i in range(self.n_samples):
            # select a locale at random => will allow us to generate internally consistent city-country pairs
            # or name/email pairs. Problem is that not all countries might be able to generate all of these
            # attributes. For example Belgium can't create IP-addresses
            locale = np.random.choice(locale_list)
            while True:
                new_id = fake.random_int(min=1, max=self.n_samples)
                if new_id not in used_ids:
                    used_ids.add(new_id)
                    break

            gender = np.random.choice(["Male", "Female"], p=[0.5, 0.5])
            # this works, but it's technical debt, talk to Léo about it
            if gender == "male":
                first_name = fake[locale].first_name_male()
            else:
                first_name = fake[locale].first_name_female()
            last_name = fake[locale].last_name()
            row = {
                "id": new_id,
                "first_name": first_name,
                "last_name": last_name,
                # take everything before @, and replace with first name.lastname
                "email": re.sub(r'^(.*?)@', first_name + "." + last_name + "@", fake[locale].free_email()),
                "gender": gender,
                "ip_address": fake[locale].ipv4_private(),
                "nationality": fake[locale].current_country(),
                "city": fake[locale].city()
            }
            output.append(row)

        df = pd.DataFrame(output, columns=self.sensitive_columns)
        return df

# %% [markdown]
# ## Similarity check

# %%
from __future__ import annotations

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sdv.evaluation.single_table import evaluate_quality

# TODO: ML model performance 


class SimilarityCheck:

    '''
    Check the quality of the synthetic data both visually and with metrics
    '''

    def __init__(self, real_data, synthetic_data, cat_cols, metadata):
        self.real_data = real_data
        self.synthetic_data = synthetic_data
        if cat_cols is not None:
          self.cat_cols = cat_cols
        else:
          self.cat_cols = []
        self.metadata = metadata


    def comparison_columns(self):
        '''
        :return: the KL divergence for numerical variables...
        tested and works
        '''
        quality_report = evaluate_quality(
          real_data=self.real_data,
          synthetic_data=self.synthetic_data,
          metadata=self.metadata)
        print(quality_report)
        print(quality_report.get_details(property_name='Column Shapes'))


    def visual_comparison_columns(self):
        '''
        Plot data in one of three ways:
        1) numeric columns are plotted using the densities
        2) categorical columns with limited categories are plotted with bar plots
        3) categorical columns with many categories do not show the values, if performance looks problematic
        we encourage further exploration of these columns
        '''
        if (self.real_data.columns != self.synthetic_data.columns).all():
            print('Columns in real and synthetic data not the same!')
            return

        fig, ax = plt.subplots(nrows=len(self.real_data.columns), figsize=(10, len(self.real_data.columns)*4))
        fig.tight_layout(pad = 5)
        for i, column in enumerate(self.real_data.columns):
            if column not in self.cat_cols:
                sns.kdeplot(self.real_data[column], ax=ax[i], label='Real', fill=True, color='c')
                sns.kdeplot(self.synthetic_data[column], ax=ax[i], label='Synthetic', fill=True, color='m')
            elif len(self.real_data[column].unique()) <= 5:
                sns.histplot(data = self.real_data,x = column, ax=ax[i],bins = len(self.real_data[column].unique()), label='Real', stat = 'density', color='c',discrete = False,element = 'step')
                sns.histplot(data = self.synthetic_data,x = column, ax=ax[i], bins = len(self.real_data[column].unique()),label='Synthetic', stat = "density", color='m',discrete = False ,element = 'step')
            else:
                sns.histplot(data = self.real_data,x = column, ax=ax[i], label='Real', fill = False,stat = 'density', color='c',discrete = False,element = 'step')
                sns.histplot(data = self.synthetic_data,x = column, ax=ax[i], label='Synthetic', fill = False,stat = "density", color='m',discrete = False ,element = 'step')
                ax[i].set_xticklabels([])
            ax[i].set_title(f'Comparison of {column}')
            ax[i].autoscale_view()
            ax[i].set_xlabel(column)
            ax[i].legend()
        plt.show()

    def compare_correlations(self):
        '''
        Compare correlation matrices
        :return:
        '''
        fig, ax = plt.subplots(figsize=(len(self.real_data.columns), (len(self.real_data.columns))))
        diff_corr = abs(self.real_data.corr() - self.synthetic_data.corr())
        mask = np.tril(np.ones_like(diff_corr, dtype=bool))
        sns.heatmap(diff_corr, mask=mask)
        ax.set_title('Differences in correlation values real and synthetic data')

    def compare_model_performance(self, fitted_model_real, fitted_model_synth, X_test, y_test):
        """
        Method that computes how close the scores of a model trained on the real vs. synthetic
        data are.
        """
        score_real = fitted_model_real.score(X_test, y_test)
        score_synth = fitted_model_synth.score(X_test, y_test)
        print(f"Score on real dataset: {score_real}\nScore on synthetic dataset: {score_synth}")
        return score_real, score_synth

# %% [markdown]
# ## Use case of FRAUD DETECTION

# %% [markdown]
# ### Loading the data

# %%
df = pd.read_excel("Dataset.xlsx")
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#       Month  WeekOfMonth  DayOfWeek       Make AccidentArea DayOfWeekClaimed  \
# 0       Dec            5  Wednesday      Honda        Urban          Tuesday
# 1       Jan            3  Wednesday      Honda        Urban           Monday
# 2       Oct            5     Friday      Honda        Urban         Thursday
# 3       Jun            2   Saturday     Toyota        Rural           Friday
# 4       Feb            1   Saturday      Honda        Urban           Monday
# ...     ...          ...        ...        ...          ...              ...
# 11560   Nov            4   Thursday      Mazda        Urban           Monday
# 11561   Nov            4     Friday  Chevrolet        Urban           Monday
# 11562   Nov            4     Friday     Toyota        Urban          Tuesday
# 11563   Dec            1     Monday     Toyota        Urban         Thursday
# 11564   Dec            2  Wednesday     Toyota        Urban         Thursday
#
#       MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus   Age  \
# 0              Jan                   1  Female        Single  21.0
# 1              Jan                   4    Male        Single  34.0
# 2              Nov                   2    Male       Married  47.0
# 3              Jul                   1    Male       Married  65.0
# 4              Feb                   3    Male       Married  36.0
# ...            ...                 ...     ...           ...   ...
# 11560          Nov                   4    Male       Married  40.0
# 11561          Nov                   4    Male        Single  58.0
# 11562          Nov                   5    Male       Married  35.0
# 11563          Dec                   2  Female       Married  34.0
# 11564          Dec                   3    Male        Single  21.0
#
#                Fault          PolicyType VehicleCategory     VehiclePrice  \
# 0      Policy Holder   Sport - Liability           Sport  more than 69000
# 1      Policy Holder   Sport - Collision           Sport  more than 69000
# 2      Policy Holder   Sport - Collision           Sport  more than 69000
# 3        Third Party   Sedan - Liability           Sport   20000 to 29000
# 4        Third Party   Sport - Collision           Sport  more than 69000
# ...              ...                 ...             ...              ...
# 11560  Policy Holder   Sedan - Liability           Sport   20000 to 29000
# 11561    Third Party   Sedan - Collision           Sedan   30000 to 39000
# 11562  Policy Holder   Sedan - Collision           Sedan   20000 to 29000
# 11563    Third Party  Sedan - All Perils           Sedan   20000 to 29000
# 11564  Policy Holder   Sedan - Collision           Sedan   20000 to 29000
#
#        FraudFound_P  PolicyNumber  RepNumber  Deductible  DriverRating  \
# 0                 0             1         12         300           1.0
# 1                 0             2         15         400           4.0
# 2                 0             3          7         400           3.0
# 3                 0             4          4         400           2.0
# 4                 0             7         14         400           1.0
# ...             ...           ...        ...         ...           ...
# 11560             0         15414          9         400           2.0
# 11561             0         15415          3         400           4.0
# 11562             1         15416          5         400           4.0
# 11563             0         15419          6         400           4.0
# 11564             1         15420          3         400           4.0
#
#       Days_Policy_Accident Days_Policy_Claim PastNumberOfClaims AgeOfVehicle  \
# 0             more than 30      more than 30               none      3 years
# 1             more than 30      more than 30               none      6 years
# 2             more than 30      more than 30                  1      7 years
# 3             more than 30      more than 30                  1  more than 7
# 4             more than 30      more than 30                  1      7 years
# ...                    ...               ...                ...          ...
# 11560         more than 30      more than 30                  1      7 years
# 11561         more than 30      more than 30               none      7 years
# 11562         more than 30      more than 30             2 to 4      6 years
# 11563         more than 30      more than 30               none      2 years
# 11564         more than 30      more than 30               none      5 years
#
#       AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# 0              26 to 30                No             No  External
# 1              31 to 35               Yes             No  External
# 2              41 to 50                No             No  External
# 3              51 to 65               Yes             No  External
# 4              36 to 40                No             No  External
# ...                 ...               ...            ...       ...
# 11560          36 to 40               Yes             No  External
# 11561          51 to 65                No             No  External
# 11562          31 to 35                No             No  External
# 11563          31 to 35                No             No  External
# 11564          26 to 30                No             No  External
#
#       NumberOfSuppliments AddressChange_Claim NumberOfCars  Year  BasePolicy  \
# 0                    none              1 year       3 to 4  1994   Liability
# 1                    none           no change    1 vehicle  1994   Collision
# 2                    none           no change    1 vehicle  1994   Collision
# 3             more than 5           no change    1 vehicle  1994   Liability
# 4                  1 to 2           no change    1 vehicle  1994   Collision
# ...                   ...                 ...          ...   ...         ...
# 11560              1 to 2           no change    1 vehicle  1996   Liability
# 11561              1 to 2        4 to 8 years   2 vehicles  1996   Collision
# 11562                none           no change    1 vehicle  1996   Collision
# 11563         more than 5           no change    1 vehicle  1996  All Perils
# 11564              1 to 2           no change    1 vehicle  1996   Collision
#
#           ClaimSize
# 0      55526.069421
# 1      59294.455571
# 2      71756.941320
# 3       7584.153493
# 4      98545.374339
# ...             ...
# 11560   3161.763273
# 11561   6546.369095
# 11562   5333.907501
# 11563   7618.072430
# 11564   1605.410804
#
# [11565 rows x 34 columns]

# %%
df.dtypes
# Out:
# Month                    object
# WeekOfMonth               int64
# DayOfWeek                object
# Make                     object
# AccidentArea             object
# DayOfWeekClaimed         object
# MonthClaimed             object
# WeekOfMonthClaimed        int64
# Sex                      object
# MaritalStatus            object
# Age                     float64
# Fault                    object
# PolicyType               object
# VehicleCategory          object
# VehiclePrice             object
# FraudFound_P              int64
# PolicyNumber              int64
# RepNumber                 int64
# Deductible                int64
# DriverRating            float64
# Days_Policy_Accident     object
# Days_Policy_Claim        object
# PastNumberOfClaims       object
# AgeOfVehicle             object
# AgeOfPolicyHolder        object
# PoliceReportFiled        object
# WitnessPresent           object
# AgentType                object
# NumberOfSuppliments      object
# AddressChange_Claim      object
# NumberOfCars             object
# Year                      int64
# BasePolicy               object
# ClaimSize               float64
# dtype: object

# %% [markdown]
# ### Dropping sensitive field without predictive power

# %%
df = df.drop('PolicyNumber',axis = 1)

# %% [markdown]
# ### Identifying categorical columns and sensitive columns

# %%
cat_col = []
sensitive_cols = ['Sex','Age']

for el in list(df):
  if df[el].dtype == object:
    print(el)
    cat_col.append(el)
# Out:
# Month
# DayOfWeek
# Make
# AccidentArea
# DayOfWeekClaimed
# MonthClaimed
# Sex
# MaritalStatus
# Fault
# PolicyType
# VehicleCategory
# VehiclePrice
# Days_Policy_Accident
# Days_Policy_Claim
# PastNumberOfClaims
# AgeOfVehicle
# AgeOfPolicyHolder
# PoliceReportFiled
# WitnessPresent
# AgentType
# NumberOfSuppliments
# AddressChange_Claim
# NumberOfCars
# BasePolicy

# %%
for col in df.columns:
    unique_types = df[col].apply(type).unique()
    if len(unique_types) > 1:
        print(col, unique_types)
# Out:
# DayOfWeekClaimed [<class 'str'> <class 'int'>]
# MonthClaimed [<class 'str'> <class 'int'>]
# PastNumberOfClaims [<class 'str'> <class 'int'>]

# %%
df['PastNumberOfClaims'] = df['PastNumberOfClaims'].astype("string").astype('object')
df['DayOfWeekClaimed'] = df['DayOfWeekClaimed'].astype("string").astype('object')
df['MonthClaimed'] = df['MonthClaimed'].astype("string").astype('object')

# %% [markdown]
# ### Splitting the dataframe into train and validation

# %%
data, validation = train_test_split(df, test_size = 0.3, random_state = 42)

# %% [markdown]
# ### Splitting the dataframe into fraud and non-fraud

# %%
fraud_df = data[data['FraudFound_P'] ==1].drop('FraudFound_P',axis=1)
no_fraud_df = data[data['FraudFound_P'] ==0].drop('FraudFound_P',axis=1)

# %%
for i in list(fraud_df):
  if i not in cat_col:
    print(i,fraud_df[i].dtypes)
# Out:
# WeekOfMonth int64
# WeekOfMonthClaimed int64
# Age float64
# RepNumber int64
# Deductible int64
# DriverRating float64
# Year int64
# ClaimSize float64

# %% [markdown]
# The classes (fraud and no fraud are unbalanced). Our goal now is to synthesize both fraud and non-fraud data, but generate additional samples for the fraud data to augment the dataset and rebalance the classes.

# %%
print(len(fraud_df))
print(len(no_fraud_df))
# Out:
# 484
# 7611

# %% [markdown]
# ### Generating fraudulent & non-fraudulent data separately

# %%
generator_no_fraud = Generator(num_epochs=3, n_samples=7500, num_bootstrap = 50 ,architecture='RealTabFormer',
                          data=no_fraud_df,
                          categorical_columns=cat_col,
                          sensitive_columns=sensitive_cols)

generator_fraud = Generator(num_epochs=3, n_samples=2250, num_bootstrap = 50 ,architecture='RealTabFormer',
                          data=fraud_df,
                          categorical_columns=cat_col,
                          sensitive_columns=sensitive_cols)

generator_fraud_aug = Generator(num_epochs=3, n_samples=1750, num_bootstrap = 50 ,architecture='RealTabFormer',
                          data=fraud_df,
                          categorical_columns=cat_col,
                          sensitive_columns=sensitive_cols)
# Out:
# Retrieving metadata, check with generator.metadata
# Retrieving metadata, check with generator.metadata
# Retrieving metadata, check with generator.metadata

# %%
synth_no_fraud = generator_no_fraud.generate()
synth_fraud = generator_fraud.generate()
synth_fraud_aug = generator_fraud_aug.generate()
# Out:
# Computing the sensitivity threshold...
# /usr/local/lib/python3.10/dist-packages/realtabformer/realtabformer.py:566: UserWarning: Duplicate rate (0.0) in the data is zero. The `qt_interval` will be set                     to qt_interval_unique=100.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/realtabformer/realtabformer.py:593: UserWarning: qt_interval adjusted from 100 to 62...
#   warnings.warn(
# Bootstrap round:   0%|          | 0/50 [00:00<?, ?it/s]
# Sensitivity threshold summary:
# count    50.000000
# mean      0.000415
# std       0.003140
# min      -0.005013
# 25%      -0.001850
# 50%       0.000034
# 75%       0.002464
# max       0.009702
# dtype: float64
# Sensitivity threshold: 0.0053140984449299555 qt_max: 0.05
# Map:   0%|          | 0/7611 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='714' max='714' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [714/714 01:56, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>20</td>
#       <td>2.221800</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.135400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.038600</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.991300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.962000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.950100</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.933500</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.917000</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.920700</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.916500</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.913600</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.899000</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.894000</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.891800</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.888500</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.884100</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.882000</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.880600</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.875800</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.879700</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.874200</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.873300</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.868300</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.867000</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.865800</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.861300</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.866100</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.857500</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.858500</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.860400</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.861100</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.862500</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.857100</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.859100</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.856300</td>
#     </tr>
#   </tbody>
# </table><p>
#   0%|          | 0/3765 [00:00<?, ?it/s]
# Generated 0 invalid samples out of total 3840 samples generated. Sampling efficiency is: 100.0000%
# Critic round: 5,                     sensitivity_threshold: 0.0053140984449299555,                         val_sensitivity: 0.003669665424324209,                             val_sensitivities: [0.005409973011181081, -0.002108340830227477, 0.004821359722400718, 0.002526024932527952, 0.0022227220151651455, 0.001996530008996273, 0.00520177355095746, 0.008124277085207559, 0.007833825986377073, 0.0036081480529494927, 0.0079186479886904, 0.0010686287109626014, 0.0031197789487212436, 0.0012819688985991524, 0.002019663282354453]
#   0%|          | 0/7500 [00:00<?, ?it/s]
# Generated 0 invalid samples out of total 7552 samples generated. Sampling efficiency is: 100.0000%
# Computing the sensitivity threshold...
# /usr/local/lib/python3.10/dist-packages/realtabformer/realtabformer.py:566: UserWarning: Duplicate rate (0.0) in the data is zero. The `qt_interval` will be set                     to qt_interval_unique=100.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/realtabformer/realtabformer.py:593: UserWarning: qt_interval adjusted from 100 to 3...
#   warnings.warn(
# Bootstrap round:   0%|          | 0/50 [00:00<?, ?it/s]
# Sensitivity threshold summary:
# count    50.000000
# mean      0.001582
# std       0.012997
# min      -0.023312
# 25%      -0.007068
# 50%      -0.000527
# 75%       0.007700
# max       0.034072
# dtype: float64
# Sensitivity threshold: 0.02618143459915611 qt_max: 0.05
# Map:   0%|          | 0/484 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='45' max='45' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [45/45 00:10, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>20</td>
#       <td>2.464100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.326600</td>
#     </tr>
#   </tbody>
# </table><p>
#   0%|          | 0/237 [00:00<?, ?it/s]
# Generated 0 invalid samples out of total 256 samples generated. Sampling efficiency is: 100.0000%
# Critic round: 5,                     sensitivity_threshold: 0.02618143459915611,                         val_sensitivity: -0.010766526019690576,                             val_sensitivities: [0.003691983122362868, -0.013185654008438819, -0.013185654008438819, -0.01487341772151899, -0.011497890295358651, -0.008122362869198313, -0.014873417721518989, -0.013185654008438819, -0.01740506329113924, -0.018248945147679326, -0.004746835443037976, -0.010654008438818566, -0.009810126582278483, -0.009810126582278483, -0.00559071729957806]
#   0%|          | 0/2250 [00:00<?, ?it/s]
# Generated 0 invalid samples out of total 2304 samples generated. Sampling efficiency is: 100.0000%
# Computing the sensitivity threshold...
# /usr/local/lib/python3.10/dist-packages/realtabformer/realtabformer.py:566: UserWarning: Duplicate rate (0.0) in the data is zero. The `qt_interval` will be set                     to qt_interval_unique=100.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/realtabformer/realtabformer.py:593: UserWarning: qt_interval adjusted from 100 to 3...
#   warnings.warn(
# Bootstrap round:   0%|          | 0/50 [00:00<?, ?it/s]
# Sensitivity threshold summary:
# count    50.000000
# mean      0.001582
# std       0.012997
# min      -0.023312
# 25%      -0.007068
# 50%      -0.000527
# 75%       0.007700
# max       0.034072
# dtype: float64
# Sensitivity threshold: 0.02618143459915611 qt_max: 0.05
# Map:   0%|          | 0/484 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='45' max='45' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [45/45 00:11, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>20</td>
#       <td>2.464100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.326600</td>
#     </tr>
#   </tbody>
# </table><p>
#   0%|          | 0/237 [00:00<?, ?it/s]
# Generated 0 invalid samples out of total 256 samples generated. Sampling efficiency is: 100.0000%
# Critic round: 5,                     sensitivity_threshold: 0.02618143459915611,                         val_sensitivity: -0.010766526019690576,                             val_sensitivities: [0.003691983122362868, -0.013185654008438819, -0.013185654008438819, -0.01487341772151899, -0.011497890295358651, -0.008122362869198313, -0.014873417721518989, -0.013185654008438819, -0.01740506329113924, -0.018248945147679326, -0.004746835443037976, -0.010654008438818566, -0.009810126582278483, -0.009810126582278483, -0.00559071729957806]
#   0%|          | 0/1750 [00:00<?, ?it/s]
# Generated 0 invalid samples out of total 1792 samples generated. Sampling efficiency is: 100.0000%

# %% [markdown]
# ### Checking the similarities

# %%
similarity_checker_nofraud = SimilarityCheck(generator_no_fraud.data, synth_no_fraud, cat_col, generator_no_fraud.metadata)
similarity_checker_fraud = SimilarityCheck(generator_fraud.data, synth_fraud, cat_col, generator_fraud.metadata)
similarity_checker_fraud_aug = SimilarityCheck(generator_fraud_aug.data, synth_fraud_aug, cat_col, generator_fraud_aug.metadata)

# %%
similarity_checker_nofraud.comparison_columns()
similarity_checker_fraud.comparison_columns()
similarity_checker_fraud_aug.comparison_columns()
# Out:
# Creating report: 100%|██████████| 4/4 [00:06<00:00,  1.72s/it]
# Overall Quality Score: 97.29%
#
# Properties:
# Column Shapes: 98.03%
# Column Pair Trends: 96.56%
# <sdmetrics.reports.single_table.quality_report.QualityReport object at 0x7ff11366e7a0>
#                   Column        Metric  Quality Score
# 0            WeekOfMonth  KSComplement       0.966676
# 1     WeekOfMonthClaimed  KSComplement       0.991210
# 2                    Age  KSComplement       0.977400
# 3              RepNumber  KSComplement       0.964794
# 4             Deductible  KSComplement       0.993711
# 5           DriverRating  KSComplement       0.990774
# 6                   Year  KSComplement       0.972054
# 7              ClaimSize  KSComplement       0.980200
# 8                  Month  TVComplement       0.979890
# 9              DayOfWeek  TVComplement       0.968061
# 10                  Make  TVComplement       0.965308
# 11          AccidentArea  TVComplement       0.987368
# 12      DayOfWeekClaimed  TVComplement       0.986875
# 13          MonthClaimed  TVComplement       0.976391
# 14                   Sex  TVComplement       0.977014
# 15         MaritalStatus  TVComplement       0.984004
# 16                 Fault  TVComplement       0.987074
# 17            PolicyType  TVComplement       0.980979
# 18       VehicleCategory  TVComplement       0.983329
# 19          VehiclePrice  TVComplement       0.975727
# 20  Days_Policy_Accident  TVComplement       0.996287
# 21     Days_Policy_Claim  TVComplement       0.997411
# 22    PastNumberOfClaims  TVComplement       0.982426
# 23          AgeOfVehicle  TVComplement       0.937155
# 24     AgeOfPolicyHolder  TVComplement       0.963836
# 25     PoliceReportFiled  TVComplement       0.992016
# 26        WitnessPresent  TVComplement       0.996758
# 27             AgentType  TVComplement       0.995982
# 28   NumberOfSuppliments  TVComplement       0.985871
# 29   AddressChange_Claim  TVComplement       0.975956
# 30          NumberOfCars  TVComplement       0.972046
# 31            BasePolicy  TVComplement       0.984628
# Creating report: 100%|██████████| 4/4 [00:06<00:00,  1.74s/it]
# Overall Quality Score: 91.95%
#
# Properties:
# Column Shapes: 94.43%
# Column Pair Trends: 89.48%
# <sdmetrics.reports.single_table.quality_report.QualityReport object at 0x7ff11356e800>
#                   Column        Metric  Quality Score
# 0            WeekOfMonth  KSComplement       0.931032
# 1     WeekOfMonthClaimed  KSComplement       0.949993
# 2                    Age  KSComplement       0.956397
# 3              RepNumber  KSComplement       0.924141
# 4             Deductible  KSComplement       0.949019
# 5           DriverRating  KSComplement       0.988354
# 6                   Year  KSComplement       0.951506
# 7              ClaimSize  KSComplement       0.894823
# 8                  Month  TVComplement       0.922450
# 9              DayOfWeek  TVComplement       0.925769
# 10                  Make  TVComplement       0.862610
# 11          AccidentArea  TVComplement       0.952573
# 12      DayOfWeekClaimed  TVComplement       0.942562
# 13          MonthClaimed  TVComplement       0.880314
# 14                   Sex  TVComplement       0.974340
# 15         MaritalStatus  TVComplement       0.971346
# 16                 Fault  TVComplement       0.961344
# 17            PolicyType  TVComplement       0.924837
# 18       VehicleCategory  TVComplement       0.924837
# 19          VehiclePrice  TVComplement       0.914865
# 20  Days_Policy_Accident  TVComplement       0.979339
# 21     Days_Policy_Claim  TVComplement       0.987603
# 22    PastNumberOfClaims  TVComplement       0.971144
# 23          AgeOfVehicle  TVComplement       0.944443
# 24     AgeOfPolicyHolder  TVComplement       0.910094
# 25     PoliceReportFiled  TVComplement       0.982294
# 26        WitnessPresent  TVComplement       0.997934
# 27             AgentType  TVComplement       0.995868
# 28   NumberOfSuppliments  TVComplement       0.951568
# 29   AddressChange_Claim  TVComplement       0.925655
# 30          NumberOfCars  TVComplement       0.942448
# 31            BasePolicy  TVComplement       0.925069
# Creating report: 100%|██████████| 4/4 [00:05<00:00,  1.43s/it]
# Overall Quality Score: 92.0%
#
# Properties:
# Column Shapes: 94.49%
# Column Pair Trends: 89.5%
# <sdmetrics.reports.single_table.quality_report.QualityReport object at 0x7ff1189230d0>
#                   Column        Metric  Quality Score
# 0            WeekOfMonth  KSComplement       0.931096
# 1     WeekOfMonthClaimed  KSComplement       0.949929
# 2                    Age  KSComplement       0.956798
# 3              RepNumber  KSComplement       0.920649
# 4             Deductible  KSComplement       0.948829
# 5           DriverRating  KSComplement       0.979275
# 6                   Year  KSComplement       0.961093
# 7              ClaimSize  KSComplement       0.898250
# 8                  Month  TVComplement       0.929053
# 9              DayOfWeek  TVComplement       0.922911
# 10                  Make  TVComplement       0.862737
# 11          AccidentArea  TVComplement       0.959811
# 12      DayOfWeekClaimed  TVComplement       0.937991
# 13          MonthClaimed  TVComplement       0.886904
# 14                   Sex  TVComplement       0.970276
# 15         MaritalStatus  TVComplement       0.971410
# 16                 Fault  TVComplement       0.961535
# 17            PolicyType  TVComplement       0.920076
# 18       VehicleCategory  TVComplement       0.920647
# 19          VehiclePrice  TVComplement       0.913341
# 20  Days_Policy_Accident  TVComplement       0.979339
# 21     Days_Policy_Claim  TVComplement       0.987603
# 22    PastNumberOfClaims  TVComplement       0.965747
# 23          AgeOfVehicle  TVComplement       0.946411
# 24     AgeOfPolicyHolder  TVComplement       0.910475
# 25     PoliceReportFiled  TVComplement       0.981976
# 26        WitnessPresent  TVComplement       0.997934
# 27             AgentType  TVComplement       0.995868
# 28   NumberOfSuppliments  TVComplement       0.955124
# 29   AddressChange_Claim  TVComplement       0.931813
# 30          NumberOfCars  TVComplement       0.946893
# 31            BasePolicy  TVComplement       0.936307

# %% [markdown]
# ### Concatenate synthetic dataset (fraud + non-fraud)

# %%
synth_no_fraud['FraudFound_P'] = 0
synth_fraud['FraudFound_P'] = 1
synth_fraud_aug['FraudFound_P'] = 1

synth = pd.concat([synth_no_fraud,synth_fraud],ignore_index=True, axis = 0)
synth = synth.sample(frac=1).reset_index(drop=True)


aug_df = pd.concat([synth_fraud_aug,data],ignore_index=True, axis = 0)
aug_df = aug_df.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# ### Data preprocessing (both for synthetic & real data)

# %%
def create_dummy(col, df):
    df_dummy = pd.get_dummies(df[col], drop_first = True)
    df_dummy.columns = ['dum: ' + str(col) + ': ' + str(name) for name in df_dummy.columns]
    return df_dummy

#this function uses the previous function to create dummies for all columns that need them
def dummies(df):
    dummy_df = pd.DataFrame()
    object_cols = df.columns[df.dtypes == object]
    for col in object_cols:
        dummy_df = pd.concat([dummy_df, create_dummy(col, df)], axis = 1)
    
    df_out = pd.concat([df.drop(columns = object_cols), dummy_df.astype('int32')], axis = 1)
    return df_out.sort_index(ascending=False, axis=1)

# %%
months = {
    'Jan' : 1,
    'Feb' : 2,
    'Mar' : 3,
    'Apr' : 4,
    'May' : 5,
    'Jun' : 6,
    'Jul' : 7,
    'Aug' : 8,
    'Sep' : 9, 
    'Oct' : 10,
    'Nov' : 11,
    'Dec' : 12
          }
months_proc = lambda x: months.get(x, 0)

D_o_w = {
    'Monday': 1,
    'Tuesday': 2,
    'Wednesday': 3,
    'Thursday': 4,
    'Friday': 5,
    'Saturday': 6,
    'Sunday': 7
          }
D_o_w_proc = lambda x: D_o_w.get(x, 0)

vehicle_prices = {
    'less than 20000': 1,
    '20000 to 29000' : 2,
    '30000 to 39000' : 3,
    '40000 to 59000' : 4,
    '60000 to 69000' : 5,
    'more than 69000': 6,
          }
vehicle_price_proc = lambda x: vehicle_prices.get(x, 0)


AgeOfVehicle_variants = {
    'new'         : 0.5,
    '2 years'     : 2,
    '3 years'     : 3,
    '4 years'     : 4,
    '5 years'     : 5,
    '6 years'     : 6,
    '7 years'     : 7,
    'more than 7' : 8.5,
          }
vehicle_age_proc = lambda x: AgeOfVehicle_variants[x]

age_variants = {
    '16 to 17'     : 1,
    '18 to 20'     : 2,
    '21 to 25'     : 3,
    '26 to 30'     : 4,
    '31 to 35'     : 5,
    '36 to 40'     : 6,
    '41 to 50'     : 7,
    '51 to 65'     : 8,
    'over 65'      : 9,
          }
age_proc = lambda x: age_variants[x]



def preprocess(data):
  data = data.dropna(axis = 0)
  data = data[data['Age'] > 0.0]
  data['Month'] = data['Month'].apply(months_proc)
  data['MonthClaimed'] = data['MonthClaimed'].apply(months_proc)
  data['DayOfWeek'] = data['DayOfWeek'].apply(D_o_w_proc)
  data['DayOfWeekClaimed'] = data['DayOfWeekClaimed'].apply(D_o_w_proc)
  data['VehiclePrice'] = data['VehiclePrice'].apply(vehicle_price_proc)
  data['AgeOfVehicle'] = data['AgeOfVehicle'].apply(vehicle_age_proc)
  data['AgeOfPolicyHolder'] = data['AgeOfPolicyHolder'].apply(age_proc)
  data = dummies(data)
  return data

# %%
df.dtypes
# Out:
# Month                    object
# WeekOfMonth               int64
# DayOfWeek                object
# Make                     object
# AccidentArea             object
# DayOfWeekClaimed         object
# MonthClaimed             object
# WeekOfMonthClaimed        int64
# Sex                      object
# MaritalStatus            object
# Age                     float64
# Fault                    object
# PolicyType               object
# VehicleCategory          object
# VehiclePrice             object
# FraudFound_P              int64
# RepNumber                 int64
# Deductible                int64
# DriverRating            float64
# Days_Policy_Accident     object
# Days_Policy_Claim        object
# PastNumberOfClaims       object
# AgeOfVehicle             object
# AgeOfPolicyHolder        object
# PoliceReportFiled        object
# WitnessPresent           object
# AgentType                object
# NumberOfSuppliments      object
# AddressChange_Claim      object
# NumberOfCars             object
# Year                      int64
# BasePolicy               object
# ClaimSize               float64
# dtype: object

# %%
#preprocess real data
df_p = preprocess(data)

validation_p = preprocess(validation)

#preprocess augmented data
aug_df_p = preprocess(aug_df)

#preprocess fake data
synth_p = preprocess(synth)

# %%
for col in list(df_p):
  if col not in list(validation_p):
    validation_p[col] = 0
  if col not in list(synth_p):
    synth_p[col] = 0

# %%
for col in list(validation_p):
  if col not in list(df_p):
    df_p[col] = 0
  if col not in list(synth_p):
    synth_p[col] = 0
  if col not in list(aug_df_p):
    aug_df_p[col] = 0

# %%
validation_p = validation_p[list(df_p)]
synth_p = synth_p[list(df_p)]
aug_df_p = aug_df_p[list(df_p)]

# %%
print(df_p.shape)
print(validation_p.shape)
print(aug_df_p.shape)
print(synth_p.shape)
# Out:
# (7898, 75)
# (3403, 75)
# (9629, 75)
# (9463, 75)

# %%
#preprocess real data
X_train, X_test, y_train, y_test = train_test_split(df_p.drop("FraudFound_P", axis = 1), 
                                                    df_p["FraudFound_P"], 
                                                    test_size = 0.3, 
                                                    random_state = 42)

#preprocess fake data
X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(synth_p.drop("FraudFound_P", axis = 1), 
                                                    synth_p["FraudFound_P"], 
                                                    test_size = 0.3, 
                                                    random_state = 42)

# %% [markdown]
# ### Results evaluation function

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc

def eval_result(model, X_test, y_test, validation = False):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")

        # model predictions
        pred = model.predict(X_test)

        # classification method & confusion matrix
        print("\n", classification_report(y_test, pred, target_names = ['Not Fraud', 'Fraud']), "\n")

        display(pd.DataFrame(confusion_matrix(y_test, pred), 
                         columns = ['Predicted Not Fraud', 'Predicted Fraud'],
                         index = ['Not Fraud', 'Fraud']))
        
        print("\n")

        # feature importance
        if hasattr(model, 'feature_importances_') and not validation:
            features = pd.DataFrame({
                'Variable'  :X_test.columns,
                'Importance':model.feature_importances_
            })

            features.sort_values('Importance', ascending=False, inplace=True)
            display(features.head(20))

        # ROC curve
        fpr, tpr, _ = roc_curve(y_test, pred)
        roc_auc = auc(fpr, tpr)
        plt.figure(figsize=(6,6))
        plt.plot(fpr, tpr, color='darkred', label='ROC curve (area = %0.3f)' % roc_auc)
        plt.plot([0, 1], [0, 1], color='lightgray', linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver Operating Characteristic Curve')
        plt.legend(loc="lower right")
        plt.show()

# %% [markdown]
# ### XGBoost on original data : AUC = 0.62

# %%
xgbr = XGBClassifier(
    random_state = 1,
    n_jobs = -1,
    scale_pos_weight = 20,
    eval_metric = 'logloss'
)
xgbr.fit(X_train, y_train)
eval_result(xgbr, X_test, y_test,validation= True)
# Out:
#                precision    recall  f1-score   support
#
#    Not Fraud       0.95      0.95      0.95      3183
#        Fraud       0.27      0.29      0.28       208
#
#     accuracy                           0.91      3391
#    macro avg       0.61      0.62      0.62      3391
# weighted avg       0.91      0.91      0.91      3391
#            Predicted Not Fraud  Predicted Fraud
# Not Fraud                 3023              160
# Fraud                      148               60

# %% [markdown]
# ### XGBoost on fake + augmented data : AUC = 0.97

# %%
xgbr2 = XGBClassifier(
    random_state = 1,
    n_jobs = -1,
    scale_pos_weight = 20,
    eval_metric = 'logloss'
)
xgbr2.fit(X_train_s, y_train_s)
eval_result(xgbr2, X_test_s, y_test_s,validation= True)
# Out:
#                precision    recall  f1-score   support
#
#    Not Fraud       0.99      0.97      0.98      2902
#        Fraud       0.91      0.97      0.94       894
#
#     accuracy                           0.97      3796
#    macro avg       0.95      0.97      0.96      3796
# weighted avg       0.97      0.97      0.97      3796
#            Predicted Not Fraud  Predicted Fraud
# Not Fraud                 2821               81
# Fraud                       29              865

# %% [markdown]
# ## TESTING

# %%
#TRAIN: ORIGINAL DATA
#TEST: VALIDATION DATA
xgbr = XGBClassifier(
    random_state = 1,
    n_jobs = -1,
    scale_pos_weight = 20,
    eval_metric = 'logloss'
)
xgbr.fit(df_p.drop("FraudFound_P", axis = 1), df_p["FraudFound_P"])
eval_result(xgbr, validation_p.drop("FraudFound_P", axis = 1), validation_p["FraudFound_P"],validation= True)
# Out:
#                precision    recall  f1-score   support
#
#    Not Fraud       0.96      0.94      0.95      3210
#        Fraud       0.22      0.27      0.24       193
#
#     accuracy                           0.91      3403
#    macro avg       0.59      0.61      0.60      3403
# weighted avg       0.91      0.91      0.91      3403
#            Predicted Not Fraud  Predicted Fraud
# Not Fraud                 3028              182
# Fraud                      141               52

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()


parameters = {'n_estimators':[100,200,250],
              'criterion':['gini', 'entropy'],
              'max_depth': [10,15,20]}

clf = GridSearchCV(rf, parameters)
clf.fit(df_p.drop("FraudFound_P", axis = 1), df_p["FraudFound_P"])

clf.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 100}

# %%
from sklearn.ensemble import RandomForestClassifier

rf1 = RandomForestClassifier(criterion='gini', max_depth = 10, n_estimators= 100)

rf1.fit(df_p.drop("FraudFound_P", axis = 1), df_p["FraudFound_P"])
eval_result(rf1, validation_p.drop("FraudFound_P", axis = 1), validation_p["FraudFound_P"],validation= True)
# Out:
#                precision    recall  f1-score   support
#
#    Not Fraud       0.94      1.00      0.97      3210
#        Fraud       0.00      0.00      0.00       193
#
#     accuracy                           0.94      3403
#    macro avg       0.47      0.50      0.49      3403
# weighted avg       0.89      0.94      0.92      3403
#            Predicted Not Fraud  Predicted Fraud
# Not Fraud                 3210                0
# Fraud                      193                0

# %%
#TRAIN: AUGMENTED DATA
#TEST: VALIDATION DATA
xgbr2 = XGBClassifier(
    random_state = 1,
    n_jobs = -1,
    scale_pos_weight = 20,
    eval_metric = 'logloss'
)
xgbr2.fit(aug_df_p.drop("FraudFound_P", axis = 1), aug_df_p["FraudFound_P"])
eval_result(xgbr2, validation_p.drop("FraudFound_P", axis = 1), validation_p["FraudFound_P"],validation= True)
# Out:
#                precision    recall  f1-score   support
#
#    Not Fraud       0.96      0.88      0.92      3210
#        Fraud       0.18      0.45      0.26       193
#
#     accuracy                           0.85      3403
#    macro avg       0.57      0.66      0.59      3403
# weighted avg       0.92      0.85      0.88      3403
#            Predicted Not Fraud  Predicted Fraud
# Not Fraud                 2813              397
# Fraud                      106               87

# %%
clf2 = RandomForestClassifier(n_estimators=200)

clf2.fit(aug_df_p.drop("FraudFound_P", axis = 1), aug_df_p["FraudFound_P"])
eval_result(clf2, validation_p.drop("FraudFound_P", axis = 1), validation_p["FraudFound_P"],validation= True)
# Out:
#                precision    recall  f1-score   support
#
#    Not Fraud       0.95      0.98      0.97      3210
#        Fraud       0.30      0.11      0.16       193
#
#     accuracy                           0.93      3403
#    macro avg       0.62      0.55      0.56      3403
# weighted avg       0.91      0.93      0.92      3403
#            Predicted Not Fraud  Predicted Fraud
# Not Fraud                 3160               50
# Fraud                      172               21

# %%
#TRAIN: AUGMENTED + SYNTHETIZED DATA
#TEST: VALIDATION DATA
xgbr3 = XGBClassifier(
    random_state = 1,
    n_jobs = -1,
    scale_pos_weight = 20,
    eval_metric = 'logloss'
)
xgbr3.fit(synth_p.drop("FraudFound_P", axis = 1), synth_p["FraudFound_P"])
eval_result(xgbr3, validation_p.drop("FraudFound_P", axis = 1), validation_p["FraudFound_P"],validation= True)
# Out:
#                precision    recall  f1-score   support
#
#    Not Fraud       0.95      0.97      0.96      3210
#        Fraud       0.19      0.10      0.13       193
#
#     accuracy                           0.92      3403
#    macro avg       0.57      0.54      0.55      3403
# weighted avg       0.90      0.92      0.91      3403
#            Predicted Not Fraud  Predicted Fraud
# Not Fraud                 3124               86
# Fraud                      173               20

# %%
clf3 = RandomForestClassifier(n_estimators=200)

clf3.fit(synth_p.drop("FraudFound_P", axis = 1), synth_p["FraudFound_P"])
eval_result(clf3, validation_p.drop("FraudFound_P", axis = 1), validation_p["FraudFound_P"],validation= True)
# Out:
#                precision    recall  f1-score   support
#
#    Not Fraud       0.95      0.98      0.96      3210
#        Fraud       0.21      0.08      0.11       193
#
#     accuracy                           0.93      3403
#    macro avg       0.58      0.53      0.54      3403
# weighted avg       0.90      0.93      0.92      3403
#            Predicted Not Fraud  Predicted Fraud
# Not Fraud                 3154               56
# Fraud                      178               15
