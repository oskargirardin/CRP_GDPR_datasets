# %% [markdown]
# # Generation of synthetic time series (User Guide)
#
# **SIA PARTNERS x ESSEC/CentraleSupélec**

# %% [markdown]
# ## 0. Setup

# %% [markdown]
# ### Import libraries

# %%
# Import libraries
from sdv.datasets.local import load_csvs

# Our module
from Time_Series_SRC.ts_generator import TSGenerator
from Time_Series_SRC.ts_similarity import TSSimilarityCheck
from Time_Series_SRC.data_processing import DataProcessor
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.

# %% [markdown]
# ### Load data and get metadata

# %%
# Load the data
datasets = load_csvs(folder_name='./data/')
df = datasets["energy_dataset"]
preprocess = DataProcessor(
    df=df
)
# Out:
# /opt/anaconda3/envs/CRP3/lib/python3.10/site-packages/sdv/datasets/local.py:31: UserWarning: Ignoring incompatible files ['.DS_Store'] in folder './data/'.
#   warnings.warn(

# %%
# Create DataProcessor instance
data_processor = DataProcessor(df, obs_limit=1000, interpolate=True, drop_na_cols=True)
# The name of the time column is "time" in this dataframe and all columns can be used as identifiers in long format
# Get long dataframe and metadata
df_real = data_processor.convert_to_long_format(time_columns='time', verbose=True)
metadata = data_processor.get_metadata_long_df(identifier='variable', time_column='time', datetime_format='%Y-%m-%d %H:%M:%S')
# Out:
#                         time            variable  value
# 0  2015-01-01 00:00:00+01:00  generation biomass  447.0
# 1  2015-01-01 01:00:00+01:00  generation biomass  449.0
# 2  2015-01-01 02:00:00+01:00  generation biomass  448.0
# 3  2015-01-01 03:00:00+01:00  generation biomass  438.0
# 4  2015-01-01 04:00:00+01:00  generation biomass  428.0

# %% [markdown]
# ## 1. Train PARSynthesizer on whole dataset and create samples

# %%
# Initialize Generator
ts_gen = TSGenerator(
    df=df_real,
    metadata=metadata,
    verbose=True
)

# %%
# Train model
ts_gen.train(n_epochs=100)
# Out:
# Epoch 100 | Loss -65.39759826660156: 100%|██████████| 100/100 [01:30<00:00,  1.10it/s]

# %%
# Sample sequences
df_synth = ts_gen.sample(n_samples = 5)
# Out:
# 100%|██████████| 20/20 [01:32<00:00,  4.61s/it]

# %% [markdown]
# ## 2. Analyze similarity

# %%
# Create Similarity check
ts_sim = TSSimilarityCheck(df_real, df_synth, metadata)

# %%
# Get distance matrix if needed
distance_matrix = ts_sim.compute_distance_matrix()
distance_matrix
# Out:
#        generation biomass  generation fossil brown coal/lignite  \
# 00000          743.883592                            676.906334
# 00001          315.255377                            275.923965
# 0000a          313.545042                            283.402703
# 0000b          388.678850                            333.243378
# 0000c          374.835568                            332.016539
# 0000d          403.689666                            338.748833
# 0000e          410.178512                            352.713168
# 0000f          432.997985                            382.498504
# 0000g          370.533073                            330.485681
# 0000h          480.229691                            413.944894
# 0000i          394.123276                            347.807897
# 0000j          402.102425                            362.491218
# 0000k          343.371295                            306.073238
# 0000l          628.783268                            574.826121
# 0000m          326.414682                            284.907589
# 0000n          903.351397                            839.100445
# 0000o          457.721773                            409.794004
# 0000p          374.246640                            327.734041
# 0000q          381.318204                            339.556918
# 0000r          427.114159                            375.089167
#
#        generation fossil coal-derived gas  generation fossil gas  \
# 00000                          844.583304            1296.887570
# 00001                          366.151346            1468.098407
# 0000a                          393.123389            1308.560269
# 0000b                          485.922848            1299.342994
# 0000c                          467.280520            1299.320915
# 0000d                          498.244909            1173.782186
# 0000e                          512.922727            1202.821208
# 0000f                          519.417121            1216.046717
# 0000g                          469.097828            1436.623161
# 0000h                          586.552294            1235.484831
# 0000i                          478.045107            1281.704454
# 0000j                          494.382004            1221.978096
# 0000k                          431.107679            1494.814806
# 0000l                          707.025670            1355.655813
# 0000m                          404.839342            1360.401095
# 0000n                         1008.292753            1410.065460
# 0000o                          550.392677            1204.525409
# 0000p                          465.694960            1357.294409
# 0000q                          456.583286            1373.949149
# 0000r                          522.645597            1254.946682
#
#        generation fossil hard coal  generation fossil oil  \
# 00000                   948.441105             761.125993
# 00001                  1198.862855             318.464511
# 0000a                  1429.773650             326.855036
# 0000b                   968.156311             407.303331
# 0000c                  1298.952421             391.163039
# 0000d                   904.736636             420.613589
# 0000e                  1175.767880             432.796932
# 0000f                   774.704427             450.856459
# 0000g                   989.403717             389.096328
# 0000h                   988.778508             500.925594
# 0000i                   987.234706             405.280571
# 0000j                  1022.628938             419.250943
# 0000k                  1504.346984             357.842480
# 0000l                  1018.391481             637.776717
# 0000m                  1558.680349             334.641605
# 0000n                  1080.648316             921.533079
# 0000o                   849.586744             474.438685
# 0000p                  1373.874572             388.491928
# 0000q                  1233.700278             391.591104
# 0000r                  1078.103813             447.425404
#
#        generation fossil oil shale  generation fossil peat  \
# 00000                   844.583304              844.583304
# 00001                   366.151346              366.151346
# 0000a                   393.123389              393.123389
# 0000b                   485.922848              485.922848
# 0000c                   467.280520              467.280520
# 0000d                   498.244909              498.244909
# 0000e                   512.922727              512.922727
# 0000f                   519.417121              519.417121
# 0000g                   469.097828              469.097828
# 0000h                   586.552294              586.552294
# 0000i                   478.045107              478.045107
# 0000j                   494.382004              494.382004
# 0000k                   431.107679              431.107679
# 0000l                   707.025670              707.025670
# 0000m                   404.839342              404.839342
# 0000n                  1008.292753             1008.292753
# 0000o                   550.392677              550.392677
# 0000p                   465.694960              465.694960
# 0000q                   456.583286              456.583286
# 0000r                   522.645597              522.645597
#
#        generation geothermal  generation hydro pumped storage aggregated  ...  \
# 00000             844.583304                                         NaN  ...
# 00001             366.151346                                         NaN  ...
# 0000a             393.123389                                         NaN  ...
# 0000b             485.922848                                         NaN  ...
# 0000c             467.280520                                         NaN  ...
# 0000d             498.244909                                         NaN  ...
# 0000e             512.922727                                         NaN  ...
# 0000f             519.417121                                         NaN  ...
# 0000g             469.097828                                         NaN  ...
# 0000h             586.552294                                         NaN  ...
# 0000i             478.045107                                         NaN  ...
# 0000j             494.382004                                         NaN  ...
# 0000k             431.107679                                         NaN  ...
# 0000l             707.025670                                         NaN  ...
# 0000m             404.839342                                         NaN  ...
# 0000n            1008.292753                                         NaN  ...
# 0000o             550.392677                                         NaN  ...
# 0000p             465.694960                                         NaN  ...
# 0000q             456.583286                                         NaN  ...
# 0000r             522.645597                                         NaN  ...
#
#        generation waste  generation wind offshore  generation wind onshore  \
# 00000        783.068967                844.583304              1109.085231
# 00001        326.725431                366.151346              1911.466134
# 0000a        341.978708                393.123389              2171.672113
# 0000b        427.650906                485.922848              1653.033612
# 0000c        408.528940                467.280520              2031.392412
# 0000d        440.152747                498.244909              1673.239356
# 0000e        450.117345                512.922727              1795.532579
# 0000f        465.812166                519.417121              1468.263325
# 0000g        406.904776                469.097828              1652.584659
# 0000h        523.030942                586.552294              1424.922966
# 0000i        422.692798                478.045107              1573.043585
# 0000j        435.632919                494.382004              1778.293351
# 0000k        374.840647                431.107679              2265.800078
# 0000l        660.142346                707.025670              1200.229922
# 0000m        350.796310                404.839342              2245.261781
# 0000n        947.041505               1008.292753              1351.095805
# 0000o        491.649256                550.392677              1418.632281
# 0000p        408.553051                465.694960              2089.746452
# 0000q        405.226654                456.583286              1969.070193
# 0000r        466.244226                522.645597              1638.957791
#
#        forecast solar day ahead  forecast wind offshore eday ahead  \
# 00000                497.535780                                NaN
# 00001                324.181234                                NaN
# 0000a                331.343563                                NaN
# 0000b                342.585853                                NaN
# 0000c                294.439401                                NaN
# 0000d                317.329909                                NaN
# 0000e                356.750471                                NaN
# 0000f                360.677690                                NaN
# 0000g                342.654356                                NaN
# 0000h                361.711410                                NaN
# 0000i                336.462745                                NaN
# 0000j                307.309924                                NaN
# 0000k                321.137992                                NaN
# 0000l                456.601889                                NaN
# 0000m                338.634197                                NaN
# 0000n                649.916584                                NaN
# 0000o                341.734156                                NaN
# 0000p                322.581551                                NaN
# 0000q                331.733563                                NaN
# 0000r                333.310205                                NaN
#
#        forecast wind onshore day ahead  total load forecast  \
# 00000                      1103.623527         14538.230064
# 00001                      1906.502619         21773.402816
# 0000a                      2168.973562         21868.615345
# 0000b                      1650.600727         21259.370700
# 0000c                      2025.231797         21848.350183
# 0000d                      1671.125661         20966.223564
# 0000e                      1792.950971         21068.960459
# 0000f                      1467.169486         20320.751927
# 0000g                      1646.135654         21243.439128
# 0000h                      1419.425756         20079.202581
# 0000i                      1564.300575         20590.601175
# 0000j                      1775.262200         21185.225771
# 0000k                      2263.283311         22298.171833
# 0000l                      1198.713175         14518.343891
# 0000m                      2242.872869         21952.625757
# 0000n                      1333.974674         12873.063740
# 0000o                      1418.600248         20004.754496
# 0000p                      2088.582585         21995.877805
# 0000q                      1964.666992         21780.512961
# 0000r                      1634.780121         20769.090150
#
#        total load actual  price day ahead  price actual
# 00000       14096.014676       827.850925    822.698857
# 00001       21737.592480       355.062442    352.258304
# 0000a       22049.101579       379.719447    375.194881
# 0000b       21152.084360       469.970016    465.449546
# 0000c       21792.714233       450.757199    445.718092
# 0000d       20903.924314       486.533213    482.720138
# 0000e       21242.791980       496.611329    492.873235
# 0000f       20263.197498       507.772092    502.538448
# 0000g       21144.912226       453.286964    447.555842
# 0000h       20242.372891       569.437309    565.071560
# 0000i       20348.890546       464.378675    459.584290
# 0000j       21266.740043       479.437254    473.425391
# 0000k       22276.014080       416.880143    412.319251
# 0000l       13867.977333       693.731492    690.012091
# 0000m       22134.310567       389.700014    384.729278
# 0000n       12377.017989       992.990333    986.666545
# 0000o       20173.911647       535.561145    530.938515
# 0000p       21966.165003       451.109842    446.734496
# 0000q       21830.640123       444.080698    438.675209
# 0000r       20919.749300       508.636701    503.897749
#
# [20 rows x 28 columns]

# %%
# For every real TS, plot its nearest neighbour
ts_sim.plot_nearest_neighbours(figsize = (20, 40))

# %% [markdown]
# ## Tips for training

# %% [markdown]
# ### Training on a single time series might help!

# %% [markdown]
# #### Training & Sampling

# %%
# Single out time series
df_wind_onshore = df_real[df_real["variable"] == "generation wind onshore"]

# Initialize Generator for generation wind onshore
ts_gen_wind = TSGenerator(
    df=df_wind_onshore,
    metadata=metadata,
    verbose=False
)

# Train model
ts_gen_wind.train(n_epochs=1000)

# Sample data
df_wind_onshore_synthetic = ts_gen_wind.sample(n_samples=5)

# %% [markdown]
# #### Evaluation

# %%
# Create Similarity check
ts_sim_wind = TSSimilarityCheck(df_wind_onshore, df_wind_onshore_synthetic, metadata)

# %%
# Plot its nearest neighbour
ts_sim_wind.plot_nearest_neighbours(figsize = (20, 5))

# %% [markdown]
# **Comment:** Due to the model training on a single time series, it is better able to capture the specifities and reduce the distance between the real and the synthetic time series. However, the model would probably benefit from training on multiple *similar* time series.
